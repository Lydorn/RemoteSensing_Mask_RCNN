# %%
# %run -i 'process_data.py'
# Out:
# Processing data...
# austin1
# /notebooks/RemoteSensing_Mask_RCNN/data/processed/train/images/austin1.0000.0000.png
# /notebooks/RemoteSensing_Mask_RCNN/data/processed/train/images/austin1.0000.0001.png
# /notebooks/RemoteSensing_Mask_RCNN/data/processed/train/images/austin1.0000.0002.png
# /notebooks/RemoteSensing_Mask_RCNN/data/processed/train/images/austin1.0000.0003.png
# /notebooks/RemoteSensing_Mask_RCNN/data/processed/train/images/austin1.0000.0004.png
# /notebooks/RemoteSensing_Mask_RCNN/data/processed/train/images/austin1.0001.0000.png
# /notebooks/RemoteSensing_Mask_RCNN/data/processed/train/images/austin1.0001.0001.png
# /notebooks/RemoteSensing_Mask_RCNN/data/processed/train/images/austin1.0001.0002.png
# /notebooks/RemoteSensing_Mask_RCNN/data/processed/train/images/austin1.0001.0003.png
# /notebooks/RemoteSensing_Mask_RCNN/data/processed/train/images/austin1.0001.0004.png
# /notebooks/RemoteSensing_Mask_RCNN/data/processed/train/images/austin1.0002.0000.png
# ...
